# %% [markdown]
# <a href="https://colab.research.google.com/github/ILoveCoder999/FederatedLearning/blob/master/fed_avg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# import module
import sys
sys.path.append('/content/drive/MyDrive')
from preprocessing import FederatedDataBuilder
# Out:
# Mounted at /content/drive

# %%
# %%writefile fed_avg_iid.py
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Subset

from preprocessing import FederatedDataBuilder


GLOBAL_DINO_BACKBONE = torch.hub.load('facebookresearch/dino:main', 'dino_vits16')



class DINOCIFAR100Fixed(nn.Module):
    """
     Uses global backbone instead of reloading each time
    """
    def __init__(self, num_classes=100):
        super().__init__()

        # Use the global backbone (not loading a new one!)
        self.backbone = GLOBAL_DINO_BACKBONE

        # Freeze backbone
        for param in self.backbone.parameters():
            param.requires_grad = False

        # Classification head (this is what we train)
        self.head = nn.Linear(384, num_classes)

        # Initialize head properly
        nn.init.xavier_uniform_(self.head.weight)
        nn.init.zeros_(self.head.bias)

    def forward(self, x):
        # Extract features
        with torch.no_grad():
            features = self.backbone(x)

        # Classify
        output = self.head(features)
        return output


def fed_avg_aggregate(global_model, local_weights, client_sample_counts):
    """Weighted averaging of local model weights"""
    global_dict = copy.deepcopy(global_model.state_dict())
    total_samples = sum(client_sample_counts)

    # Initialize to zero
    for k in global_dict.keys():
        if 'num_batches_tracked' not in k and 'backbone' not in k:
            global_dict[k] = global_dict[k] * 0.0

    # Weighted average
    for i in range(len(local_weights)):
        ratio = client_sample_counts[i] / total_samples
        weights = local_weights[i]
        for k in global_dict.keys():
            if 'num_batches_tracked' not in k and 'backbone' not in k:
                global_dict[k] += weights[k] * ratio

    return global_dict


class LocalClient:
    """Local client that trains ONLY the classification head"""

    def __init__(self, client_id, dataset, indices, device):
        self.client_id = client_id
        self.indices = indices
        self.device = device

        self.trainloader = DataLoader(
            Subset(dataset, list(indices)),
            batch_size=128,
            shuffle=True,
            num_workers=2,
            pin_memory=True
        )

    def train(self, global_weights, local_steps=4, lr=0.1):
        """Train for J=4 steps"""

        # Create model (uses global backbone, NO reloading!)
        local_model = DINOCIFAR100Fixed(num_classes=100).to(self.device)

        # Load global weights
        local_model.load_state_dict(global_weights, strict=False)
        local_model.train()

        # Only train the head, backbone stays frozen
        optimizer = optim.SGD(
            local_model.head.parameters(),  # ONLY head parameters!
            lr=lr,
            momentum=0.9,
            weight_decay=1e-4,
            nesterov=True
        )

        criterion = nn.CrossEntropyLoss()

        # Train for J steps
        step_count = 0
        losses = []
        iterator = iter(self.trainloader)

        while step_count < local_steps:
            try:
                inputs, targets = next(iterator)
            except StopIteration:
                iterator = iter(self.trainloader)
                inputs, targets = next(iterator)

            inputs, targets = inputs.to(self.device), targets.to(self.device)

            optimizer.zero_grad()
            outputs = local_model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(local_model.head.parameters(), max_norm=1.0)

            optimizer.step()

            losses.append(loss.item())
            step_count += 1

        return local_model.state_dict(), sum(losses)/len(losses)


def evaluate_global(model, test_loader, device):
    """Evaluate global model"""
    model.eval()
    correct = 0
    total = 0
    loss_sum = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss_sum += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    return loss_sum / len(test_loader), 100. * correct / total


def run_fedavg_fixed(K=100, C=0.1, J=8, rounds=100, lr=0.05):
    """
    FedAvg with backbone reloading issue FIXED
    """
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print(f"\n{'='*70}")
    print(f"FedAvg with FIXED Backbone Loading")
    print(f"{'='*70}")
    print(f"K={K}, C={C}, J={J}, Rounds={rounds}")
    print(f"Learning rate: {lr}")
    print(f"Device: {DEVICE}")
    print(f"{'='*70}\n")

    # Data
    print("Preparing data...")
    data_builder = FederatedDataBuilder(val_split_ratio=0.1, K=K)
    client_dict = data_builder.get_iid_partition()
    data_builder.verify_partition(client_dict)

    test_loader = DataLoader(
        data_builder.test_dataset,
        batch_size=256,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

    # Global model
    print("\nInitializing global model...")
    global_model = DINOCIFAR100Fixed(num_classes=100).to(DEVICE)
    print("✓ Global model ready (using shared backbone)")

    history = {'loss': [], 'accuracy': [], 'round': []}

    # Training
    m = max(int(C * K), 1)
    print(f"\nStarting training with {m} clients per round...\n")

    for r in range(rounds):
        selected_clients = np.random.choice(range(K), m, replace=False)

        local_weights = []
        client_sample_counts = []
        client_losses = []

        global_weights = copy.deepcopy(global_model.state_dict())

        # Train clients
        for idx, client_idx in enumerate(selected_clients):
            client = LocalClient(
                client_id=client_idx,
                dataset=data_builder.train_dataset,
                indices=client_dict[client_idx],
                device=DEVICE
            )

            # NO backbone reloading here!
            w_local, loss_local = client.train(global_weights, local_steps=J, lr=lr)

            local_weights.append(w_local)
            client_sample_counts.append(len(client_dict[client_idx]))
            client_losses.append(loss_local)

        # Aggregate
        new_weights = fed_avg_aggregate(global_model, local_weights, client_sample_counts)
        global_model.load_state_dict(new_weights, strict=False)

        # Evaluate
        test_loss, test_acc = evaluate_global(global_model, test_loader, DEVICE)
        history['loss'].append(test_loss)
        history['accuracy'].append(test_acc)
        history['round'].append(r + 1)

        avg_client_loss = sum(client_losses) / len(client_losses)

        print(f"Round {r+1:2d}/{rounds} -> "
              f"Train Loss: {avg_client_loss:.4f} | "
              f"Test Loss: {test_loss:.4f} | "
              f"Test Acc: {test_acc:.2f}%")

    # Results
    print(f"\n{'='*70}")
    print(f"Training Complete!")
    print(f"{'='*70}")
    print(f"Final Test Accuracy: {history['accuracy'][-1]:.2f}%")
    print(f"Best Test Accuracy: {max(history['accuracy']):.2f}%")
    print(f"{'='*70}\n")

    # Plot
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history['round'], history['accuracy'], 'b-o', linewidth=2)
    plt.title('Test Accuracy (Fixed Version)', fontsize=14, fontweight='bold')
    plt.xlabel('Round')
    plt.ylabel('Accuracy (%)')
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(history['round'], history['loss'], 'r-o', linewidth=2)
    plt.title('Test Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Round')
    plt.ylabel('Loss')
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('fedavg_backbone_fixed.png', dpi=150)
    print("Figure saved: fedavg_backbone_fixed.png")
    plt.show()

    return history, global_model


if __name__ == "__main__":

    history, model = run_fedavg_fixed(
        K=100,
        C=0.1,
        J=4,
        rounds=200,
        lr=0.05
    )

    print("\n✓ Training completed!")
    print("\nComparison:")
    print("  Before fix: ~5% after 21 rounds")
    print(f"  After fix:  {history['accuracy'][-1]:.2f}% after 30 rounds")
    print("\nThis should be a significant improvement!")
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# ======================================================================
# FedAvg with FIXED Backbone Loading
# ======================================================================
# K=100, C=0.1, J=4, Rounds=200
# Learning rate: 0.05
# Device: cuda
# ======================================================================
#
# Preparing data...
# Creating IID partition for 100 clients...
#
# ==================================================
# Verifying Partition
# ==================================================
# Total samples: 45000/45000
# No overlap
# ✓ Avg classes per client: 99.0
# ==================================================
#
#
# Initializing global model...
# ✓ Global model ready (using shared backbone)
#
# Starting training with 10 clients per round...
#
# Round  1/200 -> Train Loss: 14.2776 | Test Loss: 11.9816 | Test Acc: 1.05%
# Round  2/200 -> Train Loss: 11.4305 | Test Loss: 10.4495 | Test Acc: 1.41%
# Round  3/200 -> Train Loss: 10.2416 | Test Loss: 9.5016 | Test Acc: 2.23%
# Round  4/200 -> Train Loss: 9.2698 | Test Loss: 8.7516 | Test Acc: 3.58%
# Round  5/200 -> Train Loss: 8.6089 | Test Loss: 8.1184 | Test Acc: 4.87%
# Round  6/200 -> Train Loss: 7.9581 | Test Loss: 7.5489 | Test Acc: 6.18%
# Round  7/200 -> Train Loss: 7.4166 | Test Loss: 7.0420 | Test Acc: 8.02%
# Round  8/200 -> Train Loss: 6.8808 | Test Loss: 6.5982 | Test Acc: 10.02%
# Round  9/200 -> Train Loss: 6.4823 | Test Loss: 6.1877 | Test Acc: 12.28%
# Round 10/200 -> Train Loss: 6.1932 | Test Loss: 5.8353 | Test Acc: 14.22%
# Round 11/200 -> Train Loss: 5.6749 | Test Loss: 5.5027 | Test Acc: 16.52%
# Round 12/200 -> Train Loss: 5.5063 | Test Loss: 5.2140 | Test Acc: 18.50%
# Round 13/200 -> Train Loss: 5.1245 | Test Loss: 4.9463 | Test Acc: 20.44%
# Round 14/200 -> Train Loss: 4.8600 | Test Loss: 4.7197 | Test Acc: 22.70%
# Round 15/200 -> Train Loss: 4.7037 | Test Loss: 4.5144 | Test Acc: 24.38%
# Round 16/200 -> Train Loss: 4.4559 | Test Loss: 4.3208 | Test Acc: 25.61%
# Round 17/200 -> Train Loss: 4.3423 | Test Loss: 4.1533 | Test Acc: 27.43%
# Round 18/200 -> Train Loss: 4.1880 | Test Loss: 3.9962 | Test Acc: 28.89%
# Round 19/200 -> Train Loss: 3.9882 | Test Loss: 3.8592 | Test Acc: 30.18%
# Round 20/200 -> Train Loss: 3.8534 | Test Loss: 3.7338 | Test Acc: 31.67%
# Round 21/200 -> Train Loss: 3.7423 | Test Loss: 3.6124 | Test Acc: 32.86%
# Round 22/200 -> Train Loss: 3.5092 | Test Loss: 3.5070 | Test Acc: 33.92%
# Round 23/200 -> Train Loss: 3.4359 | Test Loss: 3.4118 | Test Acc: 35.43%
# Round 24/200 -> Train Loss: 3.3606 | Test Loss: 3.3200 | Test Acc: 36.29%
# Round 25/200 -> Train Loss: 3.2172 | Test Loss: 3.2365 | Test Acc: 37.06%
# Round 26/200 -> Train Loss: 3.1139 | Test Loss: 3.1555 | Test Acc: 38.30%
# Round 27/200 -> Train Loss: 3.1473 | Test Loss: 3.0785 | Test Acc: 38.87%
# Round 28/200 -> Train Loss: 2.9947 | Test Loss: 3.0087 | Test Acc: 39.46%
# Round 29/200 -> Train Loss: 2.9836 | Test Loss: 2.9540 | Test Acc: 40.48%
# Round 30/200 -> Train Loss: 2.9126 | Test Loss: 2.8810 | Test Acc: 41.40%
# Round 31/200 -> Train Loss: 2.8252 | Test Loss: 2.8268 | Test Acc: 42.22%
# Round 32/200 -> Train Loss: 2.7027 | Test Loss: 2.7700 | Test Acc: 43.22%
# Round 33/200 -> Train Loss: 2.7145 | Test Loss: 2.7240 | Test Acc: 43.48%
# Round 34/200 -> Train Loss: 2.6655 | Test Loss: 2.6667 | Test Acc: 44.28%
# Round 35/200 -> Train Loss: 2.5495 | Test Loss: 2.6309 | Test Acc: 44.89%
# Round 36/200 -> Train Loss: 2.5315 | Test Loss: 2.5801 | Test Acc: 45.64%
# Round 37/200 -> Train Loss: 2.5340 | Test Loss: 2.5483 | Test Acc: 46.00%
# Round 38/200 -> Train Loss: 2.5038 | Test Loss: 2.5134 | Test Acc: 46.74%
# Round 39/200 -> Train Loss: 2.4482 | Test Loss: 2.4753 | Test Acc: 47.04%
# Round 40/200 -> Train Loss: 2.4402 | Test Loss: 2.4279 | Test Acc: 47.47%
# Round 41/200 -> Train Loss: 2.2692 | Test Loss: 2.3974 | Test Acc: 48.04%
# Round 42/200 -> Train Loss: 2.3736 | Test Loss: 2.3703 | Test Acc: 48.43%
# Round 43/200 -> Train Loss: 2.1892 | Test Loss: 2.3412 | Test Acc: 48.98%
# Round 44/200 -> Train Loss: 2.2564 | Test Loss: 2.3096 | Test Acc: 49.52%
# Round 45/200 -> Train Loss: 2.1953 | Test Loss: 2.2867 | Test Acc: 49.68%
# Round 46/200 -> Train Loss: 2.2139 | Test Loss: 2.2524 | Test Acc: 50.09%
# Round 47/200 -> Train Loss: 2.1831 | Test Loss: 2.2331 | Test Acc: 50.23%
# Round 48/200 -> Train Loss: 2.1451 | Test Loss: 2.2075 | Test Acc: 50.72%
# Round 49/200 -> Train Loss: 2.1266 | Test Loss: 2.1820 | Test Acc: 51.27%
# Round 50/200 -> Train Loss: 2.0914 | Test Loss: 2.1624 | Test Acc: 51.55%
# Round 51/200 -> Train Loss: 2.0730 | Test Loss: 2.1275 | Test Acc: 51.89%
# Round 52/200 -> Train Loss: 1.9708 | Test Loss: 2.1065 | Test Acc: 52.51%
# Round 53/200 -> Train Loss: 2.0327 | Test Loss: 2.0904 | Test Acc: 52.56%
# Round 54/200 -> Train Loss: 2.0465 | Test Loss: 2.0814 | Test Acc: 52.97%
# Round 55/200 -> Train Loss: 1.9739 | Test Loss: 2.0517 | Test Acc: 53.00%
# Round 56/200 -> Train Loss: 1.9514 | Test Loss: 2.0302 | Test Acc: 53.24%
# Round 57/200 -> Train Loss: 1.9490 | Test Loss: 2.0133 | Test Acc: 53.44%
# Round 58/200 -> Train Loss: 1.8922 | Test Loss: 2.0046 | Test Acc: 53.91%
# Round 59/200 -> Train Loss: 2.0037 | Test Loss: 1.9786 | Test Acc: 54.18%
# Round 60/200 -> Train Loss: 1.9195 | Test Loss: 1.9635 | Test Acc: 54.62%
# Round 61/200 -> Train Loss: 1.8650 | Test Loss: 1.9499 | Test Acc: 54.56%
# Round 62/200 -> Train Loss: 1.8610 | Test Loss: 1.9370 | Test Acc: 55.07%
# Round 63/200 -> Train Loss: 1.7576 | Test Loss: 1.9218 | Test Acc: 55.20%
# Round 64/200 -> Train Loss: 1.8070 | Test Loss: 1.9079 | Test Acc: 55.04%
# Round 65/200 -> Train Loss: 1.8665 | Test Loss: 1.8926 | Test Acc: 55.64%
# Round 66/200 -> Train Loss: 1.8445 | Test Loss: 1.8796 | Test Acc: 55.84%
# Round 67/200 -> Train Loss: 1.8382 | Test Loss: 1.8621 | Test Acc: 56.02%
# Round 68/200 -> Train Loss: 1.6575 | Test Loss: 1.8524 | Test Acc: 56.15%
# Round 69/200 -> Train Loss: 1.7396 | Test Loss: 1.8314 | Test Acc: 56.47%
# Round 70/200 -> Train Loss: 1.7570 | Test Loss: 1.8211 | Test Acc: 56.64%
# Round 71/200 -> Train Loss: 1.7280 | Test Loss: 1.8052 | Test Acc: 57.02%
# Round 72/200 -> Train Loss: 1.6807 | Test Loss: 1.8100 | Test Acc: 57.03%
# Round 73/200 -> Train Loss: 1.7270 | Test Loss: 1.7876 | Test Acc: 57.09%
# Round 74/200 -> Train Loss: 1.7020 | Test Loss: 1.7755 | Test Acc: 57.50%
# Round 75/200 -> Train Loss: 1.6204 | Test Loss: 1.7674 | Test Acc: 57.41%
# Round 76/200 -> Train Loss: 1.6671 | Test Loss: 1.7507 | Test Acc: 57.93%
# Round 77/200 -> Train Loss: 1.5778 | Test Loss: 1.7471 | Test Acc: 57.99%
# Round 78/200 -> Train Loss: 1.6069 | Test Loss: 1.7310 | Test Acc: 57.99%
# Round 79/200 -> Train Loss: 1.5437 | Test Loss: 1.7252 | Test Acc: 58.19%
# Round 80/200 -> Train Loss: 1.5920 | Test Loss: 1.7146 | Test Acc: 58.57%
# Round 81/200 -> Train Loss: 1.6277 | Test Loss: 1.7093 | Test Acc: 58.62%
# Round 82/200 -> Train Loss: 1.5900 | Test Loss: 1.6995 | Test Acc: 58.97%
# Round 83/200 -> Train Loss: 1.6107 | Test Loss: 1.6919 | Test Acc: 58.94%
# Round 84/200 -> Train Loss: 1.5592 | Test Loss: 1.6768 | Test Acc: 59.23%
# Round 85/200 -> Train Loss: 1.5797 | Test Loss: 1.6694 | Test Acc: 59.15%
# Round 86/200 -> Train Loss: 1.5314 | Test Loss: 1.6671 | Test Acc: 59.66%
# Round 87/200 -> Train Loss: 1.5260 | Test Loss: 1.6576 | Test Acc: 59.44%
# Round 88/200 -> Train Loss: 1.4533 | Test Loss: 1.6481 | Test Acc: 59.79%
# Round 89/200 -> Train Loss: 1.5414 | Test Loss: 1.6340 | Test Acc: 60.02%
# Round 90/200 -> Train Loss: 1.4603 | Test Loss: 1.6259 | Test Acc: 60.03%
# Round 91/200 -> Train Loss: 1.5598 | Test Loss: 1.6202 | Test Acc: 60.22%
# Round 92/200 -> Train Loss: 1.4946 | Test Loss: 1.6190 | Test Acc: 60.37%
# Round 93/200 -> Train Loss: 1.4797 | Test Loss: 1.6068 | Test Acc: 60.53%
# Round 94/200 -> Train Loss: 1.4779 | Test Loss: 1.6067 | Test Acc: 60.54%
# Round 95/200 -> Train Loss: 1.4213 | Test Loss: 1.5927 | Test Acc: 60.70%
# Round 96/200 -> Train Loss: 1.5417 | Test Loss: 1.5883 | Test Acc: 60.89%
# Round 97/200 -> Train Loss: 1.4146 | Test Loss: 1.5827 | Test Acc: 61.30%
# Round 98/200 -> Train Loss: 1.4160 | Test Loss: 1.5810 | Test Acc: 60.95%
# Round 99/200 -> Train Loss: 1.4434 | Test Loss: 1.5750 | Test Acc: 60.99%
# Round 100/200 -> Train Loss: 1.4469 | Test Loss: 1.5656 | Test Acc: 61.29%
# Round 101/200 -> Train Loss: 1.4387 | Test Loss: 1.5541 | Test Acc: 61.50%
# Round 102/200 -> Train Loss: 1.3734 | Test Loss: 1.5602 | Test Acc: 61.30%
# Round 103/200 -> Train Loss: 1.4399 | Test Loss: 1.5420 | Test Acc: 61.83%
# Round 104/200 -> Train Loss: 1.4448 | Test Loss: 1.5379 | Test Acc: 61.77%
# Round 105/200 -> Train Loss: 1.4101 | Test Loss: 1.5307 | Test Acc: 61.90%
# Round 106/200 -> Train Loss: 1.4177 | Test Loss: 1.5174 | Test Acc: 62.06%
# Round 107/200 -> Train Loss: 1.3835 | Test Loss: 1.5152 | Test Acc: 62.12%
# Round 108/200 -> Train Loss: 1.3886 | Test Loss: 1.5093 | Test Acc: 62.09%
# Round 109/200 -> Train Loss: 1.4043 | Test Loss: 1.5077 | Test Acc: 62.53%
# Round 110/200 -> Train Loss: 1.3760 | Test Loss: 1.5058 | Test Acc: 62.31%
# Round 111/200 -> Train Loss: 1.3691 | Test Loss: 1.4914 | Test Acc: 62.35%
# Round 112/200 -> Train Loss: 1.3328 | Test Loss: 1.4915 | Test Acc: 62.85%
# Round 113/200 -> Train Loss: 1.3140 | Test Loss: 1.4828 | Test Acc: 62.84%
# Round 114/200 -> Train Loss: 1.3132 | Test Loss: 1.4784 | Test Acc: 62.89%
# Round 115/200 -> Train Loss: 1.3028 | Test Loss: 1.4676 | Test Acc: 63.14%
# Round 116/200 -> Train Loss: 1.2968 | Test Loss: 1.4714 | Test Acc: 63.11%
# Round 117/200 -> Train Loss: 1.3862 | Test Loss: 1.4695 | Test Acc: 63.34%
# Round 118/200 -> Train Loss: 1.3226 | Test Loss: 1.4613 | Test Acc: 63.04%
# Round 119/200 -> Train Loss: 1.2653 | Test Loss: 1.4612 | Test Acc: 63.01%
# Round 120/200 -> Train Loss: 1.3003 | Test Loss: 1.4514 | Test Acc: 63.55%
# Round 121/200 -> Train Loss: 1.2742 | Test Loss: 1.4429 | Test Acc: 63.31%
# Round 122/200 -> Train Loss: 1.2825 | Test Loss: 1.4390 | Test Acc: 63.85%
# Round 123/200 -> Train Loss: 1.2925 | Test Loss: 1.4388 | Test Acc: 63.79%
# Round 124/200 -> Train Loss: 1.2751 | Test Loss: 1.4303 | Test Acc: 63.76%
# Round 125/200 -> Train Loss: 1.1943 | Test Loss: 1.4325 | Test Acc: 64.02%
# Round 126/200 -> Train Loss: 1.2913 | Test Loss: 1.4248 | Test Acc: 63.81%
# Round 127/200 -> Train Loss: 1.3005 | Test Loss: 1.4271 | Test Acc: 63.78%
# Round 128/200 -> Train Loss: 1.2806 | Test Loss: 1.4204 | Test Acc: 64.26%
# Round 129/200 -> Train Loss: 1.2469 | Test Loss: 1.4131 | Test Acc: 64.38%
# Round 130/200 -> Train Loss: 1.2541 | Test Loss: 1.4116 | Test Acc: 64.04%
# Round 131/200 -> Train Loss: 1.2524 | Test Loss: 1.4073 | Test Acc: 64.38%
# Round 132/200 -> Train Loss: 1.2143 | Test Loss: 1.3957 | Test Acc: 64.42%
# Round 133/200 -> Train Loss: 1.1824 | Test Loss: 1.3973 | Test Acc: 64.59%
# Round 134/200 -> Train Loss: 1.1307 | Test Loss: 1.3965 | Test Acc: 64.62%
# Round 135/200 -> Train Loss: 1.2669 | Test Loss: 1.3785 | Test Acc: 64.69%
# Round 136/200 -> Train Loss: 1.1754 | Test Loss: 1.3834 | Test Acc: 64.60%
# Round 137/200 -> Train Loss: 1.2036 | Test Loss: 1.3831 | Test Acc: 64.85%
# Round 138/200 -> Train Loss: 1.2480 | Test Loss: 1.3753 | Test Acc: 65.04%
# Round 139/200 -> Train Loss: 1.2050 | Test Loss: 1.3647 | Test Acc: 65.19%
# Round 140/200 -> Train Loss: 1.2294 | Test Loss: 1.3669 | Test Acc: 65.04%
# Round 141/200 -> Train Loss: 1.1828 | Test Loss: 1.3641 | Test Acc: 65.13%
# Round 142/200 -> Train Loss: 1.2102 | Test Loss: 1.3616 | Test Acc: 65.22%
# Round 143/200 -> Train Loss: 1.1932 | Test Loss: 1.3620 | Test Acc: 65.06%
# Round 144/200 -> Train Loss: 1.2071 | Test Loss: 1.3549 | Test Acc: 65.04%
# Round 145/200 -> Train Loss: 1.1870 | Test Loss: 1.3563 | Test Acc: 65.22%
# Round 146/200 -> Train Loss: 1.2521 | Test Loss: 1.3483 | Test Acc: 65.26%
# Round 147/200 -> Train Loss: 1.1471 | Test Loss: 1.3432 | Test Acc: 65.20%
# Round 148/200 -> Train Loss: 1.1304 | Test Loss: 1.3352 | Test Acc: 65.27%
# Round 149/200 -> Train Loss: 1.1436 | Test Loss: 1.3432 | Test Acc: 65.11%
# Round 150/200 -> Train Loss: 1.0815 | Test Loss: 1.3350 | Test Acc: 65.49%
# Round 151/200 -> Train Loss: 1.1254 | Test Loss: 1.3367 | Test Acc: 65.92%
# Round 152/200 -> Train Loss: 1.2304 | Test Loss: 1.3343 | Test Acc: 65.52%
# Round 153/200 -> Train Loss: 1.1785 | Test Loss: 1.3299 | Test Acc: 65.61%
# Round 154/200 -> Train Loss: 1.1267 | Test Loss: 1.3287 | Test Acc: 65.85%
# Round 155/200 -> Train Loss: 1.1832 | Test Loss: 1.3216 | Test Acc: 65.69%
# Round 156/200 -> Train Loss: 1.1498 | Test Loss: 1.3160 | Test Acc: 65.99%
# Round 157/200 -> Train Loss: 1.1031 | Test Loss: 1.3186 | Test Acc: 66.03%
# Round 158/200 -> Train Loss: 1.1417 | Test Loss: 1.3117 | Test Acc: 66.05%
# Round 159/200 -> Train Loss: 1.1118 | Test Loss: 1.3101 | Test Acc: 66.09%
# Round 160/200 -> Train Loss: 1.0885 | Test Loss: 1.3012 | Test Acc: 65.99%
# Round 161/200 -> Train Loss: 1.1185 | Test Loss: 1.3013 | Test Acc: 66.46%
# Round 162/200 -> Train Loss: 1.1582 | Test Loss: 1.3030 | Test Acc: 65.92%
# Round 163/200 -> Train Loss: 1.1813 | Test Loss: 1.3016 | Test Acc: 66.33%
# Round 164/200 -> Train Loss: 1.0200 | Test Loss: 1.3025 | Test Acc: 66.02%
# Round 165/200 -> Train Loss: 1.1305 | Test Loss: 1.2985 | Test Acc: 66.47%
# Round 166/200 -> Train Loss: 1.0951 | Test Loss: 1.2996 | Test Acc: 66.14%
# Round 167/200 -> Train Loss: 1.1091 | Test Loss: 1.2932 | Test Acc: 66.29%
# Round 168/200 -> Train Loss: 1.1066 | Test Loss: 1.2835 | Test Acc: 66.42%
# Round 169/200 -> Train Loss: 1.0742 | Test Loss: 1.2818 | Test Acc: 66.53%
# Round 170/200 -> Train Loss: 1.0747 | Test Loss: 1.2866 | Test Acc: 66.60%
# Round 171/200 -> Train Loss: 1.0688 | Test Loss: 1.2764 | Test Acc: 66.54%
# Round 172/200 -> Train Loss: 1.0347 | Test Loss: 1.2799 | Test Acc: 66.67%
# Round 173/200 -> Train Loss: 1.0880 | Test Loss: 1.2719 | Test Acc: 66.57%
# Round 174/200 -> Train Loss: 1.0504 | Test Loss: 1.2781 | Test Acc: 66.94%
# Round 175/200 -> Train Loss: 1.0848 | Test Loss: 1.2704 | Test Acc: 66.52%
# Round 176/200 -> Train Loss: 1.0303 | Test Loss: 1.2663 | Test Acc: 66.89%
# Round 177/200 -> Train Loss: 1.0637 | Test Loss: 1.2637 | Test Acc: 66.67%
# Round 178/200 -> Train Loss: 1.0309 | Test Loss: 1.2633 | Test Acc: 66.95%
# Round 179/200 -> Train Loss: 1.0518 | Test Loss: 1.2629 | Test Acc: 66.77%
# Round 180/200 -> Train Loss: 1.0259 | Test Loss: 1.2554 | Test Acc: 67.16%
# Round 181/200 -> Train Loss: 1.1328 | Test Loss: 1.2510 | Test Acc: 67.22%
# Round 182/200 -> Train Loss: 1.0241 | Test Loss: 1.2515 | Test Acc: 67.14%
# Round 183/200 -> Train Loss: 1.0556 | Test Loss: 1.2460 | Test Acc: 67.20%
# Round 184/200 -> Train Loss: 0.9857 | Test Loss: 1.2428 | Test Acc: 67.46%
# Round 185/200 -> Train Loss: 1.0034 | Test Loss: 1.2414 | Test Acc: 67.50%
# Round 186/200 -> Train Loss: 1.0246 | Test Loss: 1.2469 | Test Acc: 66.97%
# Round 187/200 -> Train Loss: 1.0252 | Test Loss: 1.2411 | Test Acc: 67.42%
# Round 188/200 -> Train Loss: 1.0690 | Test Loss: 1.2385 | Test Acc: 67.40%
# Round 189/200 -> Train Loss: 1.0322 | Test Loss: 1.2313 | Test Acc: 67.55%
# Round 190/200 -> Train Loss: 0.9757 | Test Loss: 1.2337 | Test Acc: 67.85%
# Round 191/200 -> Train Loss: 1.0564 | Test Loss: 1.2286 | Test Acc: 67.59%
# Round 192/200 -> Train Loss: 1.0671 | Test Loss: 1.2270 | Test Acc: 67.73%
# Round 193/200 -> Train Loss: 1.0190 | Test Loss: 1.2322 | Test Acc: 67.48%
# Round 194/200 -> Train Loss: 0.9825 | Test Loss: 1.2334 | Test Acc: 67.48%
# Round 195/200 -> Train Loss: 0.9891 | Test Loss: 1.2298 | Test Acc: 67.63%
# Round 196/200 -> Train Loss: 1.0210 | Test Loss: 1.2262 | Test Acc: 67.75%
# Round 197/200 -> Train Loss: 1.0786 | Test Loss: 1.2265 | Test Acc: 67.85%
# Round 198/200 -> Train Loss: 0.9965 | Test Loss: 1.2132 | Test Acc: 68.00%
# Round 199/200 -> Train Loss: 1.0250 | Test Loss: 1.2233 | Test Acc: 67.72%
# Round 200/200 -> Train Loss: 0.9815 | Test Loss: 1.2207 | Test Acc: 67.96%
#
# ======================================================================
# Training Complete!
# ======================================================================
# Final Test Accuracy: 67.96%
# Best Test Accuracy: 68.00%
# ======================================================================
#
# Figure saved: fedavg_backbone_fixed.png
# ✓ Training completed!
#
# Comparison:
#   Before fix: ~5% after 21 rounds
#   After fix:  67.96% after 30 rounds
#
# This should be a significant improvement!
