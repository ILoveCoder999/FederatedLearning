# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# import module
import sys
sys.path.append('/content/drive/MyDrive')
from preprocessing import FederatedDataBuilder
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# 导入你已经实现的组件
from taskarithmetic import SparseSGDM, compute_fisher_sensitivity, calibrate_masks
from fed_avg_non_iid import DINOCIFAR100 # 或者使用你定义的模型
from preprocessing import FederatedDataBuilder

def run_task_arithmetic_experiment(sparsity_ratio=0.1, calibration_batches=10):
    """
    应用任务算术技术进行稀疏微调
    """
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1. 准备数据
    # 项目要求使用 CIFAR-100 [cite: 29]
    data_builder = FederatedDataBuilder(val_split_ratio=0.1)
    train_loader = DataLoader(data_builder.train_dataset, batch_size=64, shuffle=True, num_workers=4,pin_memory=True)
    test_loader = DataLoader(data_builder.test_dataset, batch_size=128, shuffle=False, num_workers=4, pin_memory=True)

    # 2. 初始化模型 (DINO ViT-S/16)
    model = DINOCIFAR100(num_classes=100).to(DEVICE)
    criterion = nn.CrossEntropyLoss()

    # ---------------------------------------------------------
    # 第一步：校准梯度掩码 (Mask Calibration)
    # ---------------------------------------------------------
    # 项目要求：通过识别“最不敏感”的参数来校准掩码
    print(f"\n--- 阶段 1: 掩码校准 (Sparsity: {sparsity_ratio}, Batches: {calibration_batches}) ---")

    # 计算敏感度分数 (基于对角费舍尔信息矩阵)
    sensitivity_scores = compute_fisher_sensitivity(
        model, train_loader, criterion, DEVICE, num_batches=calibration_batches
    )

    # 生成掩码：选择最不敏感 (least-sensitive) 的参数进行更新
    # keep_least_sensitive=True 表示敏感度越低，掩码越可能为 1 (允许更新)
    masks = calibrate_masks(
        sensitivity_scores,
        sparsity_ratio=sparsity_ratio,
        keep_least_sensitive=True
    )

    # 统计掩码信息
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    active_params = sum(m.sum().item() for m in masks.values())
    print(f"掩码校准完成。可更新参数占比: {100 * active_params / total_params:.2f}%")

    # ---------------------------------------------------------
    # 第二步：使用 SparseSGDM 进行稀疏微调
    # ---------------------------------------------------------
    # 项目要求：使用 SparseSGDM 并在微调时应用掩码 [cite: 70]
    print("\n--- 阶段 2: 稀疏微调 ---")

    # 初始化你的 SparseSGDM
    optimizer = SparseSGDM(
        model.parameters(),
        lr=0.1,
        momentum=0.9,
        weight_decay=1e-4,
        masks=masks # 传入校准好的掩码
    )

    history = {'train_loss': [], 'test_acc': []}

    # 运行几个微调 Epoch
    epochs = 30
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()

            # SparseSGDM 会在这一步根据掩码过滤梯度 [cite: 55]
            optimizer.step()

            running_loss += loss.item()

        # 评估
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
                outputs = model(inputs)
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()

        acc = 100. * correct / total
        avg_loss = running_loss / len(train_loader)
        history['train_loss'].append(avg_loss)
        history['test_acc'].append(acc)

        print(f"Epoch {epoch+1}/{epochs} | Loss: {avg_loss:.4f} | Test Acc: {acc:.2f}%")

    return history

if __name__ == "__main__":
    # 项目建议实验不同的稀疏比例 [cite: 72]
    ratios = [0.5, 0.7]
    for r in ratios:
        print(f"\n{'='*50}")
        print(f"实验开始: Sparsity Ratio = {r}")
        run_task_arithmetic_experiment(sparsity_ratio=r)
# Out:
# ======================================================================
# Loading DINO backbone (ONE TIME ONLY)...
# ======================================================================
# Downloading: "https://github.com/facebookresearch/dino/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/dino/dino_deitsmall16_pretrain/dino_deitsmall16_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dino_deitsmall16_pretrain.pth
# 100%|██████████| 82.7M/82.7M [00:00<00:00, 271MB/s]
# ✓ DINO backbone loaded and cached globally
# ======================================================================
#
# ==================================================
# 实验开始: Sparsity Ratio = 0.5
# 100%|██████████| 169M/169M [00:02<00:00, 78.0MB/s]
# --- 阶段 1: 掩码校准 (Sparsity: 0.5, Batches: 10) ---
# Calculating sensitivity over 10 batches...
# 掩码校准完成。可更新参数占比: 50.00%
#
# --- 阶段 2: 稀疏微调 ---
# Epoch 1/30 | Loss: 4.4010 | Test Acc: 29.74%
# Epoch 2/30 | Loss: 2.9891 | Test Acc: 41.24%
# Epoch 3/30 | Loss: 2.7687 | Test Acc: 52.96%
# Epoch 4/30 | Loss: 2.6470 | Test Acc: 38.26%
# Epoch 5/30 | Loss: 2.5951 | Test Acc: 46.99%
# Epoch 6/30 | Loss: 2.5358 | Test Acc: 53.68%
# Epoch 7/30 | Loss: 2.4929 | Test Acc: 55.37%
# Epoch 8/30 | Loss: 2.4542 | Test Acc: 55.94%
# Epoch 9/30 | Loss: 2.4249 | Test Acc: 51.29%
# Epoch 10/30 | Loss: 2.4209 | Test Acc: 37.07%
# Epoch 11/30 | Loss: 2.4119 | Test Acc: 55.85%
# Epoch 12/30 | Loss: 2.3650 | Test Acc: 47.97%
# Epoch 13/30 | Loss: 2.3623 | Test Acc: 55.93%
# Epoch 14/30 | Loss: 2.3259 | Test Acc: 55.25%
# Epoch 15/30 | Loss: 2.3242 | Test Acc: 48.26%
# Epoch 16/30 | Loss: 2.3103 | Test Acc: 55.08%
# Epoch 17/30 | Loss: 2.2951 | Test Acc: 56.92%
# Epoch 18/30 | Loss: 2.2877 | Test Acc: 45.94%
# Epoch 19/30 | Loss: 2.2769 | Test Acc: 51.69%
# Epoch 20/30 | Loss: 2.2536 | Test Acc: 55.84%
# Epoch 21/30 | Loss: 2.2328 | Test Acc: 56.36%
# Epoch 22/30 | Loss: 2.2194 | Test Acc: 46.56%
# Epoch 23/30 | Loss: 2.2161 | Test Acc: 56.59%
# Epoch 24/30 | Loss: 2.2017 | Test Acc: 57.49%
# Epoch 25/30 | Loss: 2.1908 | Test Acc: 50.74%
# Epoch 26/30 | Loss: 2.1968 | Test Acc: 56.48%
# Epoch 27/30 | Loss: 2.1781 | Test Acc: 52.01%
# Epoch 28/30 | Loss: 2.1720 | Test Acc: 51.49%
# Epoch 29/30 | Loss: 2.1714 | Test Acc: 49.98%
# Epoch 30/30 | Loss: 2.1536 | Test Acc: 49.41%
#
# ==================================================
# 实验开始: Sparsity Ratio = 0.7
#
# --- 阶段 1: 掩码校准 (Sparsity: 0.7, Batches: 10) ---
# Calculating sensitivity over 10 batches...
# 掩码校准完成。可更新参数占比: 70.00%
#
# --- 阶段 2: 稀疏微调 ---
# Epoch 1/30 | Loss: 3.4798 | Test Acc: 54.39%
# Epoch 2/30 | Loss: 2.1801 | Test Acc: 46.70%
# Epoch 3/30 | Loss: 1.9823 | Test Acc: 48.35%
# Epoch 4/30 | Loss: 1.8609 | Test Acc: 57.99%
# Epoch 5/30 | Loss: 1.7738 | Test Acc: 53.05%
# Epoch 6/30 | Loss: 1.7162 | Test Acc: 59.36%
# Epoch 7/30 | Loss: 1.6835 | Test Acc: 47.21%
# Epoch 8/30 | Loss: 1.6642 | Test Acc: 62.58%
# Epoch 9/30 | Loss: 1.6093 | Test Acc: 63.13%
# Epoch 10/30 | Loss: 1.5703 | Test Acc: 50.56%
# Epoch 11/30 | Loss: 1.5690 | Test Acc: 60.99%
# Epoch 12/30 | Loss: 1.5435 | Test Acc: 57.79%
# Epoch 13/30 | Loss: 1.5365 | Test Acc: 55.29%
# Epoch 14/30 | Loss: 1.5244 | Test Acc: 65.51%
# Epoch 15/30 | Loss: 1.4946 | Test Acc: 63.65%
# Epoch 16/30 | Loss: 1.4854 | Test Acc: 56.74%
# Epoch 17/30 | Loss: 1.4893 | Test Acc: 57.57%
# Epoch 18/30 | Loss: 1.4778 | Test Acc: 63.44%
# Epoch 19/30 | Loss: 1.4518 | Test Acc: 62.43%
# Epoch 20/30 | Loss: 1.4404 | Test Acc: 36.78%
# Epoch 21/30 | Loss: 1.4753 | Test Acc: 59.68%
# Epoch 22/30 | Loss: 1.4295 | Test Acc: 63.04%
# Epoch 23/30 | Loss: 1.4243 | Test Acc: 63.05%
# Epoch 24/30 | Loss: 1.3970 | Test Acc: 64.81%
# Epoch 25/30 | Loss: 1.4075 | Test Acc: 46.01%
# Epoch 26/30 | Loss: 1.4036 | Test Acc: 63.46%
# Epoch 27/30 | Loss: 1.4056 | Test Acc: 65.68%
# Epoch 28/30 | Loss: 1.3984 | Test Acc: 57.58%
# Epoch 29/30 | Loss: 1.3874 | Test Acc: 65.62%
# Epoch 30/30 | Loss: 1.3784 | Test Acc: 65.78%
