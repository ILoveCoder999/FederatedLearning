# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# import module
import sys
sys.path.append('/content/drive/MyDrive')
from preprocessing import FederatedDataBuilder
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# 导入你已经实现的组件
from taskarithmetic import SparseSGDM, compute_fisher_sensitivity, calibrate_masks
from fed_avg_non_iid import DINOCIFAR100 # 或者使用你定义的模型
from preprocessing import FederatedDataBuilder

def run_task_arithmetic_experiment(sparsity_ratio=0.1, calibration_batches=10):
    """
    应用任务算术技术进行稀疏微调
    """
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1. 准备数据
    # 项目要求使用 CIFAR-100 [cite: 29]
    data_builder = FederatedDataBuilder(val_split_ratio=0.1)
    train_loader = DataLoader(data_builder.train_dataset, batch_size=64, shuffle=True, num_workers=4,pin_memory=True)
    test_loader = DataLoader(data_builder.test_dataset, batch_size=128, shuffle=False, num_workers=4, pin_memory=True)

    # 2. 初始化模型 (DINO ViT-S/16)
    model = DINOCIFAR100(num_classes=100).to(DEVICE)
    criterion = nn.CrossEntropyLoss()

    # ---------------------------------------------------------
    # 第一步：校准梯度掩码 (Mask Calibration)
    # ---------------------------------------------------------
    # 项目要求：通过识别“最不敏感”的参数来校准掩码
    print(f"\n--- 阶段 1: 掩码校准 (Sparsity: {sparsity_ratio}, Batches: {calibration_batches}) ---")

    # 计算敏感度分数 (基于对角费舍尔信息矩阵)
    sensitivity_scores = compute_fisher_sensitivity(
        model, train_loader, criterion, DEVICE, num_batches=calibration_batches
    )

    # 生成掩码：选择最不敏感 (least-sensitive) 的参数进行更新
    # keep_least_sensitive=True 表示敏感度越低，掩码越可能为 1 (允许更新)
    masks = calibrate_masks(
        sensitivity_scores,
        sparsity_ratio=sparsity_ratio,
        keep_least_sensitive=True
    )

    # 统计掩码信息
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    active_params = sum(m.sum().item() for m in masks.values())
    print(f"掩码校准完成。可更新参数占比: {100 * active_params / total_params:.2f}%")

    # ---------------------------------------------------------
    # 第二步：使用 SparseSGDM 进行稀疏微调
    # ---------------------------------------------------------
    # 项目要求：使用 SparseSGDM 并在微调时应用掩码 [cite: 70]
    print("\n--- 阶段 2: 稀疏微调 ---")

    # 初始化你的 SparseSGDM
    optimizer = SparseSGDM(
        model.parameters(),
        lr=0.1,
        momentum=0.9,
        weight_decay=1e-4,
        masks=masks # 传入校准好的掩码
    )

    history = {'train_loss': [], 'test_acc': []}

    # 运行几个微调 Epoch
    epochs = 30
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()

            # SparseSGDM 会在这一步根据掩码过滤梯度 [cite: 55]
            optimizer.step()

            running_loss += loss.item()

        # 评估
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
                outputs = model(inputs)
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()

        acc = 100. * correct / total
        avg_loss = running_loss / len(train_loader)
        history['train_loss'].append(avg_loss)
        history['test_acc'].append(acc)

        print(f"Epoch {epoch+1}/{epochs} | Loss: {avg_loss:.4f} | Test Acc: {acc:.2f}%")

    return history

if __name__ == "__main__":
    # 项目建议实验不同的稀疏比例 [cite: 72]
    ratios = [0.05, 0.1, 0.2，0.5]
    for r in ratios:
        print(f"\n{'='*50}")
        print(f"实验开始: Sparsity Ratio = {r}")
        run_task_arithmetic_experiment(sparsity_ratio=r)
# Out:
# ==================================================
# 实验开始: Sparsity Ratio = 0.05
#
# --- 阶段 1: 掩码校准 (Sparsity: 0.05, Batches: 10) ---
# Calculating sensitivity over 10 batches...
# 掩码校准完成。可更新参数占比: 5.00%
#
# --- 阶段 2: 稀疏微调 ---
# Epoch 1/30 | Loss: 12.2153 | Test Acc: 6.57%
# Epoch 2/30 | Loss: 11.2057 | Test Acc: 7.51%
# Epoch 3/30 | Loss: 10.9074 | Test Acc: 8.04%
# Epoch 4/30 | Loss: 10.7073 | Test Acc: 8.60%
# Epoch 5/30 | Loss: 10.5432 | Test Acc: 4.30%
# Epoch 6/30 | Loss: 10.4463 | Test Acc: 8.97%
# Epoch 7/30 | Loss: 10.2934 | Test Acc: 8.85%
# Epoch 8/30 | Loss: 10.1778 | Test Acc: 8.93%
# Epoch 9/30 | Loss: 10.0765 | Test Acc: 9.62%
# Epoch 10/30 | Loss: 9.9828 | Test Acc: 9.33%
# Epoch 11/30 | Loss: 9.8866 | Test Acc: 9.43%
# Epoch 12/30 | Loss: 9.7988 | Test Acc: 9.89%
# Epoch 13/30 | Loss: 9.7182 | Test Acc: 9.68%
# Epoch 14/30 | Loss: 9.6304 | Test Acc: 9.48%
# Epoch 15/30 | Loss: 9.5559 | Test Acc: 9.75%
# Epoch 16/30 | Loss: 9.4750 | Test Acc: 9.60%
# Epoch 17/30 | Loss: 9.4022 | Test Acc: 9.80%
# Epoch 18/30 | Loss: 9.3282 | Test Acc: 9.58%
# Epoch 19/30 | Loss: 9.2572 | Test Acc: 9.68%
# Epoch 20/30 | Loss: 9.1965 | Test Acc: 9.94%
# Epoch 21/30 | Loss: 9.1182 | Test Acc: 9.89%
# Epoch 22/30 | Loss: 9.0520 | Test Acc: 9.75%
# Epoch 23/30 | Loss: 8.9894 | Test Acc: 9.89%
# Epoch 24/30 | Loss: 8.9266 | Test Acc: 9.85%
# Epoch 25/30 | Loss: 8.8664 | Test Acc: 10.12%
# Epoch 26/30 | Loss: 8.7986 | Test Acc: 10.03%
# Epoch 27/30 | Loss: 8.7427 | Test Acc: 10.38%
# Epoch 28/30 | Loss: 8.6790 | Test Acc: 10.26%
# Epoch 29/30 | Loss: 8.6158 | Test Acc: 9.94%
# Epoch 30/30 | Loss: 8.5654 | Test Acc: 9.96%
#
# ==================================================
# 实验开始: Sparsity Ratio = 0.1
#
# --- 阶段 1: 掩码校准 (Sparsity: 0.1, Batches: 10) ---
# Calculating sensitivity over 10 batches...
# 掩码校准完成。可更新参数占比: 10.00%
#
# --- 阶段 2: 稀疏微调 ---
# Epoch 1/30 | Loss: 11.6113 | Test Acc: 11.26%
# Epoch 2/30 | Loss: 10.1393 | Test Acc: 13.26%
# Epoch 3/30 | Loss: 9.7393 | Test Acc: 14.23%
# Epoch 4/30 | Loss: 9.5054 | Test Acc: 14.06%
# Epoch 5/30 | Loss: 9.3193 | Test Acc: 15.11%
# Epoch 6/30 | Loss: 9.1743 | Test Acc: 14.99%
# Epoch 7/30 | Loss: 9.0478 | Test Acc: 15.47%
# Epoch 8/30 | Loss: 8.9295 | Test Acc: 15.74%
# Epoch 9/30 | Loss: 8.8288 | Test Acc: 15.81%
# Epoch 10/30 | Loss: 8.7286 | Test Acc: 15.58%
# Epoch 11/30 | Loss: 8.6349 | Test Acc: 15.83%
# Epoch 12/30 | Loss: 8.5502 | Test Acc: 15.71%
# Epoch 13/30 | Loss: 8.4644 | Test Acc: 16.27%
# Epoch 14/30 | Loss: 8.3785 | Test Acc: 16.57%
# Epoch 15/30 | Loss: 8.2969 | Test Acc: 15.76%
# Epoch 16/30 | Loss: 8.2288 | Test Acc: 16.27%
# Epoch 17/30 | Loss: 8.1533 | Test Acc: 16.39%
# Epoch 18/30 | Loss: 8.0842 | Test Acc: 16.10%
# Epoch 19/30 | Loss: 8.0099 | Test Acc: 16.46%
# Epoch 20/30 | Loss: 7.9450 | Test Acc: 16.15%
# Epoch 21/30 | Loss: 7.8763 | Test Acc: 15.10%
# Epoch 22/30 | Loss: 7.8183 | Test Acc: 16.66%
# Epoch 23/30 | Loss: 7.7484 | Test Acc: 16.61%
# Epoch 24/30 | Loss: 7.6939 | Test Acc: 16.43%
# Epoch 25/30 | Loss: 7.6343 | Test Acc: 16.21%
# Epoch 26/30 | Loss: 7.5724 | Test Acc: 16.29%
# Epoch 27/30 | Loss: 7.5150 | Test Acc: 16.88%
# Epoch 28/30 | Loss: 7.4539 | Test Acc: 16.77%
# Epoch 29/30 | Loss: 7.3969 | Test Acc: 16.54%
# Epoch 30/30 | Loss: 7.3489 | Test Acc: 16.69%
#
# ==================================================
# 实验开始: Sparsity Ratio = 0.2
#
# --- 阶段 1: 掩码校准 (Sparsity: 0.2, Batches: 10) ---
# Calculating sensitivity over 10 batches...
# 掩码校准完成。可更新参数占比: 20.00%
#
# --- 阶段 2: 稀疏微调 ---
# Epoch 1/30 | Loss: 7.9531 | Test Acc: 26.21%
# Epoch 2/30 | Loss: 6.2789 | Test Acc: 29.00%
# Epoch 3/30 | Loss: 5.9694 | Test Acc: 30.48%
# Epoch 4/30 | Loss: 5.8043 | Test Acc: 31.26%
# Epoch 5/30 | Loss: 5.6893 | Test Acc: 31.73%
# Epoch 6/30 | Loss: 5.6057 | Test Acc: 32.13%
# Epoch 7/30 | Loss: 5.5331 | Test Acc: 32.37%
# Epoch 8/30 | Loss: 5.4599 | Test Acc: 32.58%
# Epoch 9/30 | Loss: 5.4034 | Test Acc: 32.26%
# Epoch 10/30 | Loss: 5.3547 | Test Acc: 33.29%
# Epoch 11/30 | Loss: 5.3047 | Test Acc: 32.09%
# Epoch 12/30 | Loss: 5.2634 | Test Acc: 33.24%
# Epoch 13/30 | Loss: 5.2104 | Test Acc: 29.40%
# Epoch 14/30 | Loss: 5.1752 | Test Acc: 33.28%
# Epoch 15/30 | Loss: 5.1322 | Test Acc: 33.21%
# Epoch 16/30 | Loss: 5.0898 | Test Acc: 33.45%
# Epoch 17/30 | Loss: 5.0541 | Test Acc: 33.70%
# Epoch 18/30 | Loss: 5.0169 | Test Acc: 33.12%
# Epoch 19/30 | Loss: 4.9825 | Test Acc: 33.74%
# Epoch 20/30 | Loss: 4.9430 | Test Acc: 33.85%
# Epoch 21/30 | Loss: 4.9070 | Test Acc: 34.20%
# Epoch 22/30 | Loss: 4.8816 | Test Acc: 33.30%
# Epoch 23/30 | Loss: 4.8456 | Test Acc: 34.21%
# Epoch 24/30 | Loss: 4.8116 | Test Acc: 33.95%
# Epoch 25/30 | Loss: 4.7813 | Test Acc: 34.08%
# Epoch 26/30 | Loss: 4.7473 | Test Acc: 33.07%
# Epoch 27/30 | Loss: 4.7180 | Test Acc: 34.17%
# Epoch 28/30 | Loss: 4.6843 | Test Acc: 34.00%
# Epoch 29/30 | Loss: 4.6515 | Test Acc: 34.62%
# Epoch 30/30 | Loss: 4.6265 | Test Acc: 33.95%
